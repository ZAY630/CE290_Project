# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
database = pd.read_csv('db_responses.csv', usecols=['Season', 'City', 'Building type', 'Cooling strategy', \
    'Thermal sensation', 'Air temperature (°C)', 'Operative temperature (°C)', 'Radiant temperature (°C)', \
        'Globe temperature (°C)', 'Relative humidity (%)', 'Air velocity (m/s)'])

# %%
database[database['Cooling strategy'] == 'Naturally Ventilated'] = 0
database[database['Cooling strategy'] == 'Air Conditioned'] = 1
database[database['Cooling strategy'] == 'Mixed Mode'] = 2
set(database['Cooling strategy'])

# %%
plt.figure(figsize=[5, 5])
plt.plot(database['Air temperature (°C)'], alpha=0.5)
plt.plot(database['Radiant temperature (°C)'], alpha=0.5)
